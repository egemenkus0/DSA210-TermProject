# %% [markdown]
# # Data Analyzing
#
# Load and inspect the processed datasets. (from raw+processed output. (they are supposed to be in the "/" folder of the project))

# %%
import pandas as pd

pd.options.display.float_format = '{:.2f}'.format

burnout = pd.read_csv('burnout_processed.csv')
health  = pd.read_csv('health_processed.csv', parse_dates=['date'])

print('Burnout:', burnout.shape)
print('Health: ', health.shape)
# Out:
# Burnout: (1000000, 22)
# Health:  (577, 10)

# %% [markdown]
# ## Burnout Dataset – Basic Info
#
# This gives the columns and the dataset size which is 1 million.

# %%
burnout.info()
print('\nMissing values:')
print(burnout.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   age                   1000000 non-null  int64
#  1   gender                1000000 non-null  str
#  2   academic_year         1000000 non-null  int64
#  3   study_hours_per_day   1000000 non-null  float64
#  4   exam_pressure         1000000 non-null  float64
#  5   academic_performance  1000000 non-null  float64
#  6   stress_level          1000000 non-null  float64
#  7   anxiety_score         1000000 non-null  float64
#  8   depression_score      1000000 non-null  float64
#  9   sleep_hours           1000000 non-null  float64
#  10  physical_activity     1000000 non-null  float64
#  11  social_support        1000000 non-null  float64
#  12  screen_time           1000000 non-null  float64
#  13  internet_usage        1000000 non-null  float64
# ...

# %%
# This gives a peek into the burnout dataset.
burnout.describe()
# Out:
#              age  academic_year  study_hours_per_day  exam_pressure  \
# count 1000000.00     1000000.00           1000000.00     1000000.00
# mean       23.00           2.50                 5.00           6.00
# std         3.74           1.12                 1.99           1.55
# min        17.00           1.00                 0.00           1.00
# 25%        20.00           2.00                 3.65           4.94
# 50%        23.00           3.00                 5.00           6.00
# 75%        26.00           4.00                 6.35           7.05
# max        29.00           4.00                14.00          10.00
#
#        academic_performance  stress_level  anxiety_score  depression_score  \
# count            1000000.00    1000000.00     1000000.00        1000000.00
# mean                  71.00          4.25           2.99              1.27
# std                    5.66          1.68           1.51              1.22
# ...

# %% [markdown]
# ## Apple Health – Basic Info
#
# This gives the columns and the dataset of my apple_health_daily data.

# %%
health.info()
print('\nMissing values:')
print(health.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          577 non-null    datetime64[us]
#  1   daily_steps                   577 non-null    float64
#  2   avg_heart_rate                7 non-null      float64
#  3   resting_heart_rate            2 non-null      float64
#  4   hrv                           4 non-null      float64
#  5   active_calories               577 non-null    float64
#  6   exercise_minutes              577 non-null    float64
#  7   distance_km                   577 non-null    float64
#  8   is_exam_period                577 non-null    int64
#  9   physical_activity_normalized  577 non-null    float64
# dtypes: datetime64[us](1), float64(8), int64(1)
# memory usage: 45.2 KB
#
# Missing values:
# date                              0
# ...

# %%
# This gives a peek into the apple health dataset.
health.describe()
# Out:
#                       date  daily_steps  avg_heart_rate  resting_heart_rate  \
# count                  577       577.00            7.00                2.00
# mean   2025-06-16 00:00:00     10379.62          129.04               88.50
# min    2024-09-01 00:00:00       539.00           94.59               74.00
# 25%    2025-01-23 00:00:00      7245.00          125.74               81.25
# 50%    2025-06-16 00:00:00     10205.00          132.04               88.50
# 75%    2025-11-07 00:00:00     13005.00          139.84               95.75
# max    2026-03-31 00:00:00     30904.00          145.51              103.00
# std                    NaN      4531.46           17.06               20.51
#
#         hrv  active_calories  exercise_minutes  distance_km  is_exam_period  \
# count  4.00           577.00            577.00       577.00          577.00
# mean  31.96             9.06              0.76         7.54            0.25
# ...
